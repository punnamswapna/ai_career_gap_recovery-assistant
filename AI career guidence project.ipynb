# %%
import pandas as pd

# %%
candidate = {
    "Name": "Swapna",
    "Education": "MTech VLSI",
    "Career_Gap_Years": 4,
    "Skills": [
        "Python",
        "Machine Learning",
        "Data Science",
        "Power BI"
    ],
    "Target_Role": "Data Scientist"
}

# %%
print("Candidate Details")
print(candidate)
# Out:
# Candidate Details
# {'Name': 'Swapna', 'Education': 'MTech VLSI', 'Career_Gap_Years': 4, 'Skills': ['Python', 'Machine Learning', 'Data Science', 'Power BI'], 'Target_Role': 'Data Scientist'}

# %%
required_skills = [
    "Python",
    "SQL",
    "Machine Learning",
    "Deep Learning",
    "Statistics",
    "Power BI",
    "Generative AI",
    "Data Visualization"
]

# %%
print("Required Skills for Data Scientist Role")
print(required_skills)
# Out:
# Required Skills for Data Scientist Role
# ['Python', 'SQL', 'Machine Learning', 'Deep Learning', 'Statistics', 'Power BI', 'Generative AI', 'Data Visualization']

# %%
missing_skills = []

for skill in required_skills:
    
    if skill not in candidate["Skills"]:
        
        missing_skills.append(skill)

print("Missing Skills")
print(missing_skills)
# Out:
# Missing Skills
# ['SQL', 'Deep Learning', 'Statistics', 'Generative AI', 'Data Visualization']

# %%
recommendations = []

for skill in missing_skills:
    
    recommendation = "Learn " + skill
    
    recommendations.append(recommendation)

print("Learning Recommendations")
print(recommendations)
# Out:
# Learning Recommendations
# ['Learn SQL', 'Learn Deep Learning', 'Learn Statistics', 'Learn Generative AI', 'Learn Data Visualization']

# %%
learning_plan = {
    
    "Month 1": [
        "Python Revision",
        "SQL Basics",
        "Statistics"
    ],
    
    "Month 2": [
        "Machine Learning Projects",
        "Data Visualization",
        "Power BI"
    ],
    
    "Month 3": [
        "Generative AI",
        "RAG",
        "LangChain Project"
    ]
}

# %%
print("3-Month Learning Roadmap")

for month, topics in learning_plan.items():
    
    print("\n", month)
    
    for topic in topics:
        
        print("-", topic)
# Out:
# 3-Month Learning Roadmap
#
#  Month 1
# - Python Revision
# - SQL Basics
# - Statistics
#
#  Month 2
# - Machine Learning Projects
# - Data Visualization
# - Power BI
#
#  Month 3
# - Generative AI
# - RAG
# - LangChain Project

# %%
job_roles = []

if "Python" in candidate["Skills"]:
    
    job_roles.append("Python Developer")

if "Machine Learning" in candidate["Skills"]:
    
    job_roles.append("Junior Data Scientist")

if "Power BI" in candidate["Skills"]:
    
    job_roles.append("Data Analyst")

print("Suitable Job Roles")
print(job_roles)
# Out:
# Suitable Job Roles
# ['Python Developer', 'Junior Data Scientist', 'Data Analyst']

# %%
message = f"""
Hello {candidate['Name']},

You already have strong foundational skills in:
{candidate['Skills']}

Your target role is:
{candidate['Target_Role']}

Even with a career gap, you can become a successful Data Scientist by consistently improving your skills.

Focus on:
1. SQL
2. Statistics
3. Generative AI
4. Real-time Projects

Keep practicing daily and continue applying for opportunities.
"""

print(message)
# Out:
# Hello Swapna,
#
# You already have strong foundational skills in:
# ['Python', 'Machine Learning', 'Data Science', 'Power BI']
#
# Your target role is:
# Data Scientist
#
# Even with a career gap, you can become a successful Data Scientist by consistently improving your skills.
#
# Focus on:
# 1. SQL
# 2. Statistics
# 3. Generative AI
# 4. Real-time Projects
#
# Keep practicing daily and continue applying for opportunities.

# %%
import pdfplumber
import pandas as pd
import google.generativeai as genai
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_2920\993808333.py:3: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   import google.generativeai as genai

# %% [raw]
# from transformers import pipeline
#
# generator = pipeline(
#     "text-generation",
#     model="gpt2"
# )
#
# response = generator(
#     "Suggest skills for a junior data scientist",
#     max_length=50
# )
#
# print(response)

# %% [raw]
# print(response[0]['generated_text'])

# %%
genai.configure(api_key="AIzaSyBP50haB1EYb4bF_0BQ3_6bfI2tD6LZtxw")

model = genai.GenerativeModel("gemini-pro")

# %%
def extract_text_from_pdf(pdf_path):
    
    text = ""
    
    with pdfplumber.open(pdf_path) as pdf:
        
        for page in pdf.pages:
            
            text += page.extract_text()
    
    return text

# %%
resume_text = extract_text_from_pdf(r"C:\Users\DELL\Downloads\swapna_punnam_data_resume (1).pdf")

print(resume_text)
# Out:
# PUNNAM SWAPNA
# +91-9182872576
# punnamswapna14@gmail.com | linkedin.com/in/punnamswapna
# GitHub: github.com/punnamswapna
# OBJECTIVE
# Machine Learning and Data Science professional with expertise in Python, ML algorithms, Deep Learning, and
# NLP. Experienced in building predictive models, performing data analysis, and mentoring students in AI/ML
# projects. Seeking opportunities to apply data-driven solutions to real-world problems.
# EXPERIENCE
# Fireblaze AI School | Data Science Trainer | Nov 2025 – Present | KPHB, Hyderabad
# • Delivered training sessions on Python, Machine Learning, Deep Learning, and Data Science concepts
# with hands-on projects.
# • Mentor students on hands-on AI/ML projects and real-world case studies.
# • Design structured curriculum including practical coding sessions and project-based learning.
# • Guide students in model building, evaluation, and deployment using Python tools.
# ...

# %%
found_skills = []

for skill in required_skills:
    
    if skill.lower() in resume_text.lower():
        
        found_skills.append(skill)

print("Detected Skills")
print(found_skills)
# Out:
# Detected Skills
# ['Python', 'SQL', 'Machine Learning', 'Deep Learning', 'Power BI', 'Data Visualization']

# %%
missing_skills = []

for skill in required_skills:
    
    if skill not in found_skills:
        
        missing_skills.append(skill)

print("Missing Skills")
print(missing_skills)
# Out:
# Missing Skills
# ['Statistics', 'Generative AI']

# %% [markdown]
# AI Resume Analysis
# Create Prompt

# %%
prompt = f"""
You are an AI Career Coach.

Analyze this resume.

Resume Content:
{resume_text}

Detected Skills:
{found_skills}

Missing Skills:
{missing_skills}

Generate:
1. Resume improvement suggestions
2. Career comeback guidance
3. Suitable job roles
4. Skills to learn
5. Confidence-building suggestions
"""

# %% [raw]
# import google.generativeai as genai
#
# genai.configure(api_key="AIzaSyBP50haB1EYb4bF_0BQ3_6bfI2tD6LZtxw")
#
# model = genai.GenerativeModel(
#     "gemini-1.5-flash"
# )

# %% [raw]
# response = model.generate_content('explain data science')
#
# print(response.text)

# %%
from transformers import pipeline

# %%
generator = pipeline(
    "text-generation",
    model="gpt2"
)
# Out:
# ...
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]

# %%
response = generator(
    prompt,
    max_length=150
)

print(response[0]['generated_text'])
# Out:
# [transformers] Passing `generation_config` together with generation-related arguments=({'max_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=150) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ...

# %%
question_prompt = f"""
Generate interview questions for:

{found_skills}

Include:
- Beginner questions
- Intermediate questions
"""

# %%
response = generator(
    question_prompt,
    max_length=100,
    do_sample=True,
    top_k=50,
    temperature=0.6
)

print(response[0]['generated_text'])
# Out:
# [transformers] Passing `generation_config` together with generation-related arguments=({'max_length', 'do_sample', 'temperature', 'top_k'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=100) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generate interview questions for:
#
# ['Python', 'SQL', 'Machine Learning', 'Deep Learning', 'Power BI', 'Data Visualization']
#
# Include:
# - Beginner questions
# - Intermediate questions
#
# - Advanced questions
#
# - Expert questions
#
# - Advanced questions
#
# - Advanced questions
#
# - Advanced questions
#
# - Advanced questions
#
# ...

# %%
chunks = resume_text.split(".")

# %%
from sentence_transformers import SentenceTransformer

# %%
embedding_model = SentenceTransformer(
    'all-MiniLM-L6-v2'
)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# C:\Users\DELL\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:138: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\DELL\.cache\huggingface\hub\models--sentence-transformers--all-MiniLM-L6-v2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ...

# %%
embeddings = embedding_model.encode(
    chunks
)

# %%
import faiss
import numpy as np

# %%
dimension = embeddings.shape[1]

index = faiss.IndexFlatL2(
    dimension
)

index.add(
    np.array(embeddings)
)

# %%
query = "What are the candidate strongest skills?"

# %%
query_embedding = embedding_model.encode(
    [query]
)

# %%
D, I = index.search(
    np.array(query_embedding),
    k=2
)

print(I)
# Out:
# [[13  4]]

# %%
for i in I[0]:

    print(chunks[i])
# Out:
# Stat Mind AI Technologies | Machine Learning Trainer| Nov 2022 – Aug 2024, Hyderabad
# • Trained students in Python, Data Science, and Machine Learning
# • Assisted students in developing real-time ML projects
# • Provided mentorship and doubt-solving sessions
# Artificial Penetration Software Solutions Pvt Ltd | Data Analyst | July 2020 – Aug 2021, Hyderabad
# • Performed Exploratory Data Analysis (EDA) on finance and banking datasets
# • Created visualizations using Matplotlib and Seaborn
# • Identified trends and patterns to support data-driven decisions
# TECHNICAL SKILLS
#  Programming: Python (Pandas, NumPy, Scikit-learn, TensorFlow, Keras)
#  Machine Learning: Regression, Classification, Clustering, Feature Engineering, Model Evaluation
#  Deep Learning: Neural Networks (CNN, RNN), Transfer Learning
#  NLP & Computer Vision: Text Preprocessing, Sentiment Analysis, Image Classification
#  Data Visualization: Matplotlib, Seaborn, Plotly
# ...
